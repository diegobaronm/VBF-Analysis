# %%
import ROOT
from ROOT import gStyle
import numpy as np
# Out:
# Welcome to JupyROOT 6.20/04

# %%
histos_no_rebin=["delta_phi_cuts_butphi","tau_phi","lep_phi","delta_phi","tau_nprongs_cuts","tau_nprongs",
                 "tau_phi_cuts","lep_phi_cuts","delta_phi_cuts",
                 
                "tau_nprongs_cuts_tpt",
                 "tau_phi_cuts_tpt","lep_phi_cuts_tpt","delta_phi_cuts_tpt","omega_bdte_btag_iso_rnn_pte_mle_mreco_tpt",
                 "bdt_e_score_btag_iso_rnn_pte_omega_mle_mreco_tpt","rnn_score_1prong_bdte_btag_iso_pte_omega_mle_mreco_tpt",
                 "rnn_score_3prong_bdte_btag_iso_pte_omega_mle_mreco_tpt"]
histos_rebin=["reco_mass_bdte_btag_iso_rnn_pte_omega_mle_tpt","Z_pt_cuts_outside","Z_pt_cuts_inside","reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega_mle",
              "reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega","reco_mass_bdte_btag_iso_rnn_pte_omega_mle",
              "reco_mass_bdte_btag_iso_rnn_pte_omega","MET_bdte_btag_iso_rnn_pte_omega_mle_mreco",
              "tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_outside","tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_inside"
              ,"lep_pt0_bdte_btag_iso_rnn_pte_omega_mle_mreco",
             
             "Z_pt_cuts_tpt_outside","Z_pt_cuts_tpt_inside","reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega_mle_tpt",
              "reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega","reco_mass_bdte_btag_iso_rnn_pte_omega_mle",
              "reco_mass_bdte_btag_iso_rnn_pte_omega","MET_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt",
              "tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt_outside","tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt_inside"
              ,"lep_pt0_bdte_btag_iso_rnn_omega_mle_mreco_tpt","lep_pt0_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt"]
histos=histos_no_rebin+histos_rebin
for i in histos:
    print(i)
    MC=ROOT.TFile.Open("MC.root","READ")
    Data = ROOT.TFile.Open("Data.root","READ")
    Signal=ROOT.TFile.Open("Signal.root","READ")
    VV=ROOT.TFile.Open("VV.root","READ")
    Wjets=ROOT.TFile.Open("Wjets.root","READ")
    Zjets=ROOT.TFile.Open("Zjets.root","READ")
    Ttbar=ROOT.TFile.Open("ttbar.root","READ")
    SingleTop=ROOT.TFile.Open("singletop.root","READ")

    gStyle.SetOptStat(1111111)
    a=i

    mc=MC.Get(a)
    data=Data.Get(a)
    signal=Signal.Get(a)
    vv=VV.Get(a)
    w=Wjets.Get(a)
    z=Zjets.Get(a)
    tt=Ttbar.Get(a)
    t=SingleTop.Get(a)

    mc.SetDirectory(0)
    signal.SetDirectory(0)
    data.SetDirectory(0)
    vv.SetDirectory(0)
    w.SetDirectory(0)
    z.SetDirectory(0)
    tt.SetDirectory(0)
    t.SetDirectory(0)
    
    s=data.GetXaxis().GetBinLowEdge(1)
    e=data.GetXaxis().GetBinUpEdge(data.GetNbinsX())

    MC.Close()
    Signal.Close()
    Data.Close()
    VV.Close()
    Wjets.Close()
    Zjets.Close()
    Ttbar.Close()
    SingleTop.Close()

    hs = ROOT.THStack("hs","")
    
    if i in histos_rebin:
        ob=data.GetNbinsX()
        n=5
        nb=int(ob/n)
        rebining=np.arange(s,e+n*(e-s)/ob,n*(e-s)/ob)
        mc=mc.Rebin(nb,"signal",rebining)
        signal=signal.Rebin(nb,"signal",rebining)
        data=data.Rebin(nb,"data",rebining)
        vv=vv.Rebin(nb,"vv",rebining)
        tt=tt.Rebin(nb,"tt",rebining)
        t=t.Rebin(nb,"t",rebining)
        z=z.Rebin(nb,"z",rebining)
        w=w.Rebin(nb,"w",rebining)

    w.SetFillColor(ROOT.kGreen)
    w.SetLineColor(ROOT.kGreen)
    z.SetFillColor(ROOT.kRed)
    z.SetLineColor(ROOT.kRed)
    vv.SetFillColor(ROOT.kBlue)
    vv.SetLineColor(ROOT.kBlue)
    tt.SetFillColor(ROOT.kYellow)
    tt.SetLineColor(ROOT.kYellow)
    t.SetFillColor(ROOT.kCyan)
    t.SetLineColor(ROOT.kCyan)
    data.SetLineColor(ROOT.kBlack)



    hs.Add(vv)
    hs.Add(t)
    hs.Add(z)
    hs.Add(tt)
    hs.Add(w)
    hs.Add(signal)

    ratio=mc.Clone()
    ratio.Divide(data)

    gStyle.SetOptStat(1111111)

    canvas3 = ROOT.TCanvas("canvas3")
    canvas3.cd()

    pad1 = ROOT . TPad (" pad1 "," pad1 " ,0 ,0.35 ,1 ,1)

    pad1.Draw ()
    pad1.cd ()




    data.Draw("pe")
    hs.Draw("HIST same")
    
    if "rnn_score" in i:
        pad1.SetLogy()


    
    data . GetYaxis (). SetRangeUser (1 ,1.2*data.GetBinContent(data.GetMaximumBin()))
    data . GetXaxis (). SetRangeUser (s ,e)
    data . GetYaxis (). SetTitle ("Events/5 GeV")

    hs . GetXaxis (). SetRangeUser (s ,e)
    legend = ROOT . TLegend (0.35 ,0.15 ,0.45 ,0.35)
    legend . AddEntry ( vv ,"Diboson")
    legend . AddEntry ( data ," Data ")
    legend . AddEntry ( signal ," Signal ")
    legend . AddEntry ( w ," W+jets ")
    legend . AddEntry ( z ," Z+jets ")
    legend . AddEntry ( t ," Single top ")
    legend . AddEntry ( tt ," ttbar ")

    legend . SetLineWidth (0)
    legend . Draw ()



    hs.SetTitle(a)

    canvas3.cd()
    pad2 = ROOT . TPad (" pad2 "," pad2 " ,0 ,0.05 ,1 ,0.38)
    pad2.Draw ()
    pad2.cd ()
    ratio.Draw ("pe")
    ratio.SetStats(0)
    ratio . GetYaxis (). SetRangeUser (0 ,2.0)
    ratio . GetXaxis (). SetRangeUser (s ,e)
    ratio . GetYaxis (). SetTitle ("MC/DATA")
    ratio . GetYaxis (). SetTitleSize (0.15)
    ratio . GetYaxis (). SetTitleOffset (0.25)
    line = ROOT . TLine (s ,1 ,e,1)
    line . SetLineColor ( ROOT . kBlack )
    line . SetLineWidth (2)
    line . Draw (" same ")


    canvas3.Print(a+".pdf")
# Out:
# delta_phi_cuts_butphi
# tau_phi
# lep_phi
# delta_phi
# tau_nprongs_cuts
# tau_nprongs
# tau_phi_cuts
# lep_phi_cuts
# delta_phi_cuts
# tau_nprongs_cuts_tpt
# tau_phi_cuts_tpt
# lep_phi_cuts_tpt
# delta_phi_cuts_tpt
# omega_bdte_btag_iso_rnn_pte_mle_mreco_tpt
# bdt_e_score_btag_iso_rnn_pte_omega_mle_mreco_tpt
# rnn_score_1prong_bdte_btag_iso_pte_omega_mle_mreco_tpt
# rnn_score_3prong_bdte_btag_iso_pte_omega_mle_mreco_tpt
# reco_mass_bdte_btag_iso_rnn_pte_omega_mle_tpt
# Z_pt_cuts_outside
# Z_pt_cuts_inside
# reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega_mle
# reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega
# reco_mass_bdte_btag_iso_rnn_pte_omega_mle
# reco_mass_bdte_btag_iso_rnn_pte_omega
# MET_bdte_btag_iso_rnn_pte_omega_mle_mreco
# tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_outside
# tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_inside
# lep_pt0_bdte_btag_iso_rnn_pte_omega_mle_mreco
# Z_pt_cuts_tpt_outside
# Z_pt_cuts_tpt_inside
# reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega_mle_tpt
# reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega
# reco_mass_bdte_btag_iso_rnn_pte_omega_mle
# reco_mass_bdte_btag_iso_rnn_pte_omega
# MET_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt
# tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt_outside
# tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt_inside
# lep_pt0_bdte_btag_iso_rnn_omega_mle_mreco_tpt
# lep_pt0_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt
# Info in <TCanvas::Print>: pdf file delta_phi_cuts_butphi.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_phi.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_phi.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file delta_phi.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_nprongs_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_nprongs.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_phi_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_phi_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file delta_phi_cuts.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_nprongs_cuts_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_phi_cuts_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_phi_cuts_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file delta_phi_cuts_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file omega_bdte_btag_iso_rnn_pte_mle_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file bdt_e_score_btag_iso_rnn_pte_omega_mle_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file rnn_score_1prong_bdte_btag_iso_pte_omega_mle_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file rnn_score_3prong_bdte_btag_iso_pte_omega_mle_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file reco_mass_bdte_btag_iso_rnn_pte_omega_mle_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega_mle.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_bdte_btag_iso_rnn_pte_omega_mle.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_bdte_btag_iso_rnn_pte_omega.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file MET_bdte_btag_iso_rnn_pte_omega_mle_mreco.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_pt0_bdte_btag_iso_rnn_pte_omega_mle_mreco.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_tpt_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file Z_pt_cuts_tpt_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega_mle_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_met_outside_bdte_btag_iso_rnn_pte_omega.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_bdte_btag_iso_rnn_pte_omega_mle.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Info in <TCanvas::Print>: pdf file reco_mass_bdte_btag_iso_rnn_pte_omega.pdf has been created
# Error in <TPad::Range>: illegal world coordinates range: x1=-37.500003, y1=0.000000, x2=337.500003, y2=0.000000
# Error in <TPad::RangeAxis>: illegal axis coordinates range: xmin=0.000000, ymin=0.000000, xmax=300.000000, ymax=0.000000
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file MET_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt_outside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file tau_pt_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt_inside.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_pt0_bdte_btag_iso_rnn_omega_mle_mreco_tpt.pdf has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas3
# Info in <TCanvas::Print>: pdf file lep_pt0_bdte_btag_iso_rnn_pte_omega_mle_mreco_tpt.pdf has been created

# %%
data.Integral(11,20)
data.GetXaxis().GetBinUpEdge(data.GetNbinsX())
# Out:
# 200.0

# %% [markdown]
# ### PLOT SINGULAR PROPERTIES

# %%
File="Wjets.root"
histo="tau_matched"

Signal=ROOT.TFile.Open(File,"READ")
signal=Signal.Get(histo)
canvas4=ROOT.TCanvas("canvas4")
canvas4.cd()
#signal=signal.Rebin(50,"signal",rebining)
signal.Draw("HIST")
signal.SetFillColor(ROOT.kGreen)
signal.SetLineColor(ROOT.kGreen)
signal.SetTitle(histo)

legend = ROOT.TLegend (0.5 ,0.5 ,0.85 ,0.55)
legend.AddEntry ( signal ,File[:-5])
legend.Draw("same")

canvas4.Print(File[:-5]+"_"+histo+".pdf")

# %% [markdown]
# ### PLOTTING BDT SCORE

# %%
canvas5=ROOT.TCanvas("canvas5")
canvas5.cd()
w.Draw("HIST")
z.Draw("HIST,same")
vv.Draw("HIST,same")
tt.Draw("HIST,same")
t.Draw("HIST,same")
signal.Draw("HIST,same")


w.SetLineColor(ROOT.kGreen)

z.SetLineColor(ROOT.kRed)

vv.SetLineColor(ROOT.kBlue)

tt.SetLineColor(ROOT.kYellow)

t.SetLineColor(ROOT.kCyan)

legend.Draw()

canvas5.SetLogy()

canvas5.Print("BDT_score.pdf")

# %%
rebining

# %%
MC=ROOT.TFile.Open("MC.root","READ")
Signal=ROOT.TFile.Open("Signal.root","READ")
VV=ROOT.TFile.Open("VV.root","READ")
Wjets=ROOT.TFile.Open("Wjets.root","READ")
Zjets=ROOT.TFile.Open("Zjet.root","READ")
Ttbar=ROOT.TFile.Open("ttbar.root","READ")
SingleTop=ROOT.TFile.Open("singletop.root","READ")

gStyle.SetOptStat(1111111)
a="reco_mass_jetn_btag_iso_bdt_tmass_omega"

mc=MC.Get(a)
signal=Signal.Get(a)
vv=VV.Get(a)
w=Wjets.Get(a)
z=Zjets.Get(a)
tt=Ttbar.Get(a)
t=SingleTop.Get(a)

mc.SetDirectory(0)
signal.SetDirectory(0)
vv.SetDirectory(0)
w.SetDirectory(0)
z.SetDirectory(0)
tt.SetDirectory(0)
t.SetDirectory(0)

MC.Close()
Signal.Close()
VV.Close()
Wjets.Close()
Zjets.Close()
Ttbar.Close()
SingleTop.Close()

hs = ROOT.THStack("hs","")
#'''
ob=300
s=0
e=300
n=6
nb=int(ob/n)
rebining=np.arange(s,e+n*(e-s)/ob,n*(e-s)/ob)
mc=mc.Rebin(nb,"signal",rebining)
signal=signal.Rebin(nb,"signal",rebining)
#data=data.Rebin(nb,"data",rebining)
vv=vv.Rebin(nb,"vv",rebining)
tt=tt.Rebin(nb,"tt",rebining)
t=t.Rebin(nb,"t",rebining)
z=z.Rebin(nb,"z",rebining)
w=w.Rebin(nb,"w",rebining)
#'''

w.SetFillColor(ROOT.kGreen)
w.SetLineColor(ROOT.kGreen)
z.SetFillColor(ROOT.kRed)
z.SetLineColor(ROOT.kRed)
vv.SetFillColor(ROOT.kBlue)
vv.SetLineColor(ROOT.kBlue)
tt.SetFillColor(ROOT.kYellow)
tt.SetLineColor(ROOT.kYellow)
t.SetFillColor(ROOT.kCyan)
t.SetLineColor(ROOT.kCyan)




hs.Add(vv)
hs.Add(w)
hs.Add(z)
hs.Add(tt)
hs.Add(t)
hs.Add(signal)




canvas6 = ROOT.TCanvas("canvas8")
canvas6.cd()


hs.Draw("HIST")

legend = ROOT . TLegend (0.8 ,0.4 ,0.9 ,0.6)
legend . AddEntry ( vv ,"Diboson")
legend . AddEntry ( signal ," Signal ")
legend . AddEntry ( w ," W+jets ")
legend . AddEntry ( z ," Z+jets ")
legend . AddEntry ( t ," Single top ")
legend . AddEntry ( tt ," ttbar ")

legend . SetLineWidth (0)
legend . Draw ()



hs.SetTitle(a)





canvas6.Print(a+".pdf")
